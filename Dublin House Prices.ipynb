# %% [markdown]
# # Dublin House Price Scraper

# %%
import pandas as pd
import requests
import re

from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver

# %% [markdown]
# ### Retrieve all Ranelagh properties for sale

# %%
# For scraping JS content
browser = webdriver.Chrome('/Users/OliverM/Code/Scraping/chromedriver')

url_d6 = 'http://www.daft.ie/dublin/houses-for-sale/dublin-6/?s%5Bsort_by%5D=price&s%5Bsort_type%5D=d'
url_d4 = 'http://www.daft.ie/dublin/houses-for-sale/dublin-4/?s%5Bsort_by%5D=price&s%5Bsort_type%5D=d'

# %%
browser.get(url_d6) #navigate to the page
innerHTML = browser.execute_script("return document.body.innerHTML")
soup6 = BeautifulSoup(innerHTML, 'lxml')

# %%
browser.get(url_d4) #navigate to the page
innerHTML = browser.execute_script("return document.body.innerHTML")
soup4 = BeautifulSoup(innerHTML, 'lxml')

# %% [markdown]
# ### Extract price of each property

# %%
price4 = soup4.find_all("strong", {"class": "price"})
price6 = soup6.find_all("strong", {"class": "price"})
price = price4 + price6

clean_prices = []
for i in price:
    clean = i.text.strip()
    clean_prices.append(clean)


for n, i in enumerate(clean_prices):
    num = i[1:len(i)]
    clean_prices[n] = num

# %% [markdown]
# ### Extract address and link of each property

# %%
address4 = soup4.select('div div h2 a')
address6 = soup6.select('div div h2 a')
address = address4 + address6

clean_address = []
clean_address2 = []
clean_links = []
for i in address:
    txt = i.text.strip()
    clean_address.append(txt)
    clean_links.append(i['href'])

for i in clean_address:
    clean_txt = i.split(', Dublin', 1)[0].strip()
    clean_address2.append(clean_txt)

# %% [markdown]
# ### For each property, extract floor area, description

# %%
clean_floor_area = []
clean_desc = []

for i in clean_links:
    prop_url = 'http://www.daft.ie/'+ i
    browser = webdriver.Chrome('/Users/OliverM/Code/Scraping/chromedriver')
    browser.get(prop_url) #navigate to the page
    innerHTML_desc = browser.execute_script("return document.body.innerHTML")
    soup_desc = BeautifulSoup(innerHTML_desc, 'lxml')
    
    space = soup_desc.find_all('div', {'class': 'description_block'})
    sqm = space[1].text.strip()
    clean_floor_area.append(sqm)
    
    desc = soup_desc.find_all('span', {'class': 'header_text'})
    for n, i in enumerate(desc):
        desc_strip = i.text.strip()
        desc[n] = desc_strip
    clean_desc.append(desc)

# %%
for n, i in enumerate(clean_floor_area):
    if 'Overall Floor Area:' not in i:
        clean_floor_area[n] = ''

# %%
clean_floor_area_strip = []

for i in clean_floor_area:
    sqm_clean = i.split('Sq. Metres', 1)[0]
    sqm_clean = sqm_clean.split('Overall Floor Area: ', 1)[-1]
    clean_floor_area_strip.append(sqm_clean)

# %% [markdown]
# ### Create DataFrame

# %%
df = pd.DataFrame({'Address': clean_address2, 
                   'Description': clean_desc,
                   'Price': clean_prices, 
                   'Link': clean_links, 
                   'Floor Area': clean_floor_area, 
                   'Sqm': clean_floor_area_strip})

# %%
df['Price'] = df['Price'].str.replace(',', '')
df[['Price','Sqm']] = df[['Price','Sqm']].apply(pd.to_numeric)
df['Description'] = df['Description'].apply(lambda x: ', '.join(x))

# %%
df['Price / Sqm'] = df['Price'] / df['Sqm']

# %%
file_date = datetime.now().strftime("%y%m%d")
df.to_csv(file_date + ' - Dublin Property Prices.csv', index=False)

# %%
# test_url = 'http://www.daft.ie/dublin/apartments-for-sale/ranelagh/44-cullenswood-house-northbrook-avenue-ranelagh-dublin-1519797/'
# browser = webdriver.Chrome('/Users/OliverM/Code/Scraping/chromedriver')
# browser.get(test_url) #navigate to the page
# innerHTML_test = browser.execute_script("return document.body.innerHTML")
# soup_test = BeautifulSoup(innerHTML_test, 'lxml')

# %%
df
# Out:
#                                       Address  \
# 0                  81 Park Avenue, Sandymount
# 1                 25 Raglan Road, Ballsbridge
# 2             16 Wellington Road, Ballsbridge
# 3          10 Greenfield Crescent, Donnybrook
# 4                    Ballsbridge, Ballsbridge
# 5             57 Wellington Road, Ballsbridge
# 6       3 Seaview Terrace, Off Ailesbury Road
# 7             61 Wellington Road, Ballsbridge
# 8                40 Herbert Park, Ballsbridge
# 9                  22 Elgin Road, Ballsbridge
# 10               10 Edward Square, Donnybrook
# 11  Glendarragh, 70 Merrion Road, Ballsbridge
# 12                    106 Upper Leeson Street
# 13                  Merrion Road, Ballsbridge
# 14            79 Tritonville Road, Sandymount
# 15        1 Sydney Parade Avenue, Ballsbridge
# 16   The Moorings, 9 Gilford Road, Sandymount
# 17               Ardilea Crescent, Clonskeagh
# 18               1 Iveragh Court, Ballsbridge
# 19                  5 Strand Mews, Sandymount
# 20                    52 Orwell Park, Rathgar
# 21               24 Northbrook Road, Ranelagh
# 22                 82 Highfield Road, Rathgar
# 23          39 Garville Avenue Upper, Rathgar
# 24         2 Green Park, Orwell Road, Rathgar
# 25                60 Leinster Road, Rathmines
# 26   Lakelands, 113 Templeogue Road, Terenure
# 27    Eagle Lodge, 36 Rathgar Avenue, Rathgar
# 28         Dunmore, 66 Brighton Road, Rathgar
# 29         98 Lower Rathmines Road, Rathmines
# 30                 46 Rathgar Avenue, Rathgar
# 31                 46 Edenvale Road, Ranelagh
# 32               23 Frankfort Avenue, Rathgar
# 33                     Ormond Road, Rathmines
# 34           130 Lr Rathmines Road, Rathmines
# 35    4 Bedroom Mews, Garville Drive, Rathgar
# 36                13 Kenilworth Road, Rathgar
# 37                    22 Dartry Park, Rathgar
# 38                47 Fortfield Park, Terenure
# 39              68 Kenilworth Square, Rathgar
#
#                                Description  \
# 0          Detached House, 5 Beds, 3 Baths
# 1          Terraced House, 5 Beds, 4 Baths
# 2    End of Terrace House, 4 Beds, 4 Baths
# 3          Detached House, 5 Beds, 5 Baths
# 4          Detached House, 5 Beds, 4 Baths
# 5          Terraced House, 4 Beds, 2 Baths
# 6     Semi-Detached House, 6 Beds, 6 Baths
# 19  /dublin/houses-for-sale/sandymount/5-strand-me...   995000  122.82
# 20  /dublin/houses-for-sale/rathgar/52-orwell-park...  3500000  480.00
# 21  /dublin/houses-for-sale/ranelagh/24-northbrook...  2100000  314.53
# 22  /dublin/houses-for-sale/rathgar/82-highfield-r...  1850000  261.98
# 23  /dublin/houses-for-sale/rathgar/39-garville-av...  1850000  336.00
# 24  /dublin/houses-for-sale/rathgar/2-green-park-o...  1775000  230.00
# 25  /dublin/houses-for-sale/rathmines/60-leinster-...  1750000  279.00
# 26  /dublin/houses-for-sale/terenure/lakelands-113...  1695000  269.97
# 27  /dublin/houses-for-sale/rathgar/eagle-lodge-36...  1395000  250.00
# 28  /dublin/houses-for-sale/rathgar/dunmore-66-bri...  1375000  209.96
# 29  /dublin/houses-for-sale/rathmines/98-lower-rat...  1300000  347.00
# 30  /dublin/houses-for-sale/rathgar/46-rathgar-ave...  1290000  197.97
# 31  /dublin/houses-for-sale/ranelagh/46-edenvale-r...  1200000  170.00
# 32  /dublin/houses-for-sale/rathgar/23-frankfort-a...  1195000  187.94
# 33  /dublin/houses-for-sale/rathmines/ormond-road-...  1175000  203.61
# 34  /dublin/houses-for-sale/rathmines/130-lr-rathm...  1150000  324.00
# 35  /dublin/houses-for-sale/rathgar/4-bedroom-mews...  1075000  186.00
# 36  /dublin/houses-for-sale/rathgar/13-kenilworth-...  1050000  200.00
# 37  /dublin/houses-for-sale/rathgar/22-dartry-park...  1000000  144.00
# 38  /dublin/houses-for-sale/terenure/47-fortfield-...   995000  233.00
# 39  /dublin/houses-for-sale/rathgar/68-kenilworth-...   995000  230.00
#
#      Price / Sqm
# 0   14511.956590
# 1   10272.277228
# 2   12376.237624
# 3    8042.895442
# 4   16146.393972
# 5            NaN
# 6    6359.129123
# 7   10316.488897
# 8    9333.333333
# 9    6578.632601
# 10   6237.500000
# 11  11386.138614
# 12   8169.398907
# 13           NaN
# 14   6250.000000
# 15   6919.528447
# 16   7065.217391
# 17   5222.222222
# 18   8461.538462
# 19   8101.286435
# 20   7291.666667
# 21   6676.628620
# 22   7061.607756
# 23   5505.952381
# 24   7717.391304
# 25   6272.401434
# 26   6278.475386
# 27   5580.000000
# 28   6548.866451
# 29   3746.397695
# 30   6516.138809
# 31   7058.823529
# 32   6358.412259
# 33   5770.836403
# 34   3549.382716
# 35   5779.569892
# 36   5250.000000
# 37   6944.444444
# 38   4270.386266
# 39   4326.086957

# %%
df.describe()
# Out:
#               Price         Sqm   Price / Sqm
# count  4.000000e+01   38.000000     38.000000
# mean   1.943125e+06  262.408684   7375.095902
# std    9.703295e+05   91.102738   2705.145390
# min    9.950000e+05  122.820000   3549.382716
# 25%    1.190000e+06  195.817500   5894.052419
# 50%    1.472500e+06  231.500000   6627.630611
# 75%    2.762500e+06  316.367500   8086.688687
# max    4.600000e+06  480.000000  16146.393972
